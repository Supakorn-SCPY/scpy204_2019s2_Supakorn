# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
covid_data = pd.read_csv("C:/Covid-19.csv")
covid_data
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      12/04/2020   12      4  2020     34       3             Afghanistan
# 1      11/04/2020   11      4  2020     37       0             Afghanistan
# 2      10/04/2020   10      4  2020     61       1             Afghanistan
# 3      09/04/2020    9      4  2020     56       3             Afghanistan
# 4      08/04/2020    8      4  2020     30       4             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 10327  25/03/2020   25      3  2020      0       0                Zimbabwe
# 10328  24/03/2020   24      3  2020      0       1                Zimbabwe
# 10329  23/03/2020   23      3  2020      0       0                Zimbabwe
# 10330  22/03/2020   22      3  2020      1       0                Zimbabwe
# 10331  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2018
# ...

# %%
Thailand = covid_data['geoId']=='TH'
dataTH = covid_data[Thailand]
case_TH = dataTH['cases'] # cases in Thailand
total_TH = np.sum(case_TH)
print('Total case in thailand is: ',total_TH)
# Out:
# Total case in thailand is:  2551

# %%
death_TH = dataTH['deaths'] # deaths in Thailand
totald_TH = np.sum(death_TH)
print('Total death case in thailand is: ',totald_TH)
# Out:
# Total death case in thailand is:  38

# %%
TH_pop = 69428528
caseper = (total_TH/TH_pop)*100
print('Percent of Thailand case: ',caseper)
# Out:
# Percent of Thailand case:  0.003674282133707343

# %%
deathper = (totald_TH/total_TH)*100
print('Percent of Thailand death case: ',deathper)
# Out:
# Percent of Thailand death case:  1.4896119168953352

# %%
#selected country TH,AU,CA,UK,FR,DE,IT,NL,PT,ES
Australia = covid_data['geoId']=='AU'
Canada = covid_data['geoId']=='CA'
United_kingdom = covid_data['geoId']=='UK'
France = covid_data['geoId']=='FR'
Germany = covid_data['geoId']=='DE'
Italy = covid_data['geoId']=='IT'
Netherland = covid_data['geoId']=='NL'
Portugal = covid_data['geoId']=='PT'
Spain = covid_data['geoId']=='ES'

dataAU = covid_data[Australia]
case_AU = dataAU['cases'] # cases in Australia
total_AU = np.sum(case_AU)
death_AU = dataAU['deaths'] # deaths in Australia
totald_AU = np.sum(death_AU)
AU_pop = 24992369
caseper_AU = (total_AU/AU_pop)*100
deathper_AU = (totald_AU/total_AU)*100
#print(caseper_AU)

dataCA = covid_data[Canada]
case_CA = dataCA['cases'] 
total_CA = np.sum(case_CA)
death_CA = dataCA['deaths'] 
totald_CA = np.sum(death_CA)
CA_pop = 37058856
caseper_CA = (total_CA/CA_pop)*100
deathper_CA = (totald_CA/total_CA)*100

dataUK = covid_data[United_kingdom]
case_UK = dataUK['cases'] 
total_UK = np.sum(case_UK)
death_UK = dataUK['deaths'] 
totald_UK = np.sum(death_UK)
UK_pop = 66488991
caseper_UK = (total_UK/UK_pop)*100
deathper_UK = (totald_UK/total_UK)*100

dataFR = covid_data[France]
case_FR = dataFR['cases'] 
total_FR = np.sum(case_FR)
death_FR = dataFR['deaths'] 
totald_FR = np.sum(death_FR)
FR_pop = 66987244
caseper_FR = (total_FR/FR_pop)*100
deathper_FR = (totald_FR/total_FR)*100
   
dataDE = covid_data[Germany]
case_DE= dataDE['cases'] 
total_DE = np.sum(case_DE)
death_DE = dataDE['deaths'] 
totald_DE = np.sum(death_DE)
DE_pop = 82927922
caseper_DE = (total_DE/DE_pop)*100
deathper_DE = (totald_DE/total_DE)*100

dataIT = covid_data[Italy]
case_IT= dataIT['cases'] 
total_IT = np.sum(case_IT)
death_IT = dataIT['deaths'] 
totald_IT = np.sum(death_IT)
IT_pop = 60431283
caseper_IT = (total_IT/IT_pop)*100
deathper_IT = (totald_IT/total_IT)*100

dataNL = covid_data[Netherland]
case_NL= dataNL['cases'] 
total_NL = np.sum(case_NL)
death_NL = dataNL['deaths'] 
totald_NL = np.sum(death_NL)
NL_pop = 17231017
caseper_NL = (total_NL/NL_pop)*100
deathper_NL = (totald_NL/total_NL)*100

dataPT = covid_data[Portugal]
case_PT= dataPT['cases'] 
total_PT = np.sum(case_PT)
death_PT = dataPT['deaths'] 
totald_PT = np.sum(death_PT)
PT_pop = 10281762
caseper_PT = (total_PT/PT_pop)*100
deathper_PT = (totald_PT/total_PT)*100

dataES = covid_data[Spain]
case_ES= dataES['cases'] 
total_ES = np.sum(case_ES)
death_ES = dataES['deaths'] 
totald_ES = np.sum(death_ES)
ES_pop = 46723749
caseper_ES = (total_ES/ES_pop)*100
deathper_ES = (totald_ES/total_ES)*100

fig = plt.figure(1)
a=plt.scatter(caseper, deathper, alpha=0.5, cmap='plasma', s=69)
b=plt.scatter(caseper_AU, deathper_AU, alpha=0.5, cmap='plasma', s=250)
c=plt.scatter(caseper_CA, deathper_CA, alpha=0.5, cmap='plasma', s=370)
d=plt.scatter(caseper_UK, deathper_UK, alpha=0.5, cmap='plasma', s=660)
e=plt.scatter(caseper_FR, deathper_FR, alpha=0.5, cmap='plasma', s=670)
f=plt.scatter(caseper_DE, deathper_DE, alpha=0.5, cmap='plasma', s=820)
g=plt.scatter(caseper_IT, deathper_IT, alpha=0.5, cmap='plasma', s=600)
h=plt.scatter(caseper_NL, deathper_NL, alpha=0.5, cmap='plasma', s=170)
i=plt.scatter(caseper_PT, deathper_PT, alpha=0.5, cmap='plasma', s=100)
j=plt.scatter(caseper_ES, deathper_ES, alpha=0.5, cmap='plasma', s=460)
#plt.colorbar();
plt.legend((a, b, c, d, e, f, g, h, i, j),
           ('Thailnd', 'Australia', 'Canada', 'United_kingdom', 'France', 'Germany', 'Italy', 'Netherland', 'Portugal', 'Spain'),
            loc='lower right',
            fontsize=8)
plt.savefig(fname='Covid-19 scatter plot.png', dpi=400, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)
